# %% [markdown]
# # Customer Revenue Prediction
#
# The 80/20 rule has proven true for many businesses–only a small percentage of customers produce most of the revenue. As such, marketing teams are challenged to make appropriate investments in promotional strategies.
# This notebook will analyze a Google Merchandise Store (also known as GStore, where Google swag is sold) customer dataset from Kaggle competition ['Google Analytics Customer Revenue Prediction'](https://www.kaggle.com/c/ga-customer-revenue-prediction) to predict revenue per customer.

# %% [markdown]
# ### About the dataset:
#
# Each row in the dataset is one visit to the store. Targeted outputs are prediction of the natural log of the sum of all transactions per user.
#
# The data fields in the given files are
#
# * fullVisitorId- A unique identifier for each user of the Google Merchandise Store.
# * channelGrouping - The channel via which the user came to the Store.
# * date - The date on which the user visited the Store.
# * device - The specifications for the device used to access the Store.
# * geoNetwork - This section contains information about the geography of the user.
# * sessionId - A unique identifier for this visit to the store.
# * socialEngagementType - Engagement type, either "Socially Engaged" or "Not Socially Engaged".
# * totals - This section contains aggregate values across the session.
# * trafficSource - This section contains information about the Traffic Source from which the session originated.
# * visitId - An identifier for this session. This is part of the value usually stored as the _utmb cookie. This is only unique to the user. For a completely unique ID, you should use a combination of fullVisitorId and visitId.
# * visitNumber - The session number for this user. If this is the first session, then this is set to 1.
# * visitStartTime - The timestamp (expressed as POSIX time).
#
# Note: some of the fields are in json format, the dataset size is very large. The train and test datasets used in this analysis is a cvs file with json flattened from Kaggle [json flattened csv data](https://www.kaggle.com/colinpearse/ga-analytics-with-json-columns)(thanks to Collin!).

# %%
import os
import gc   # garbage collector
import numpy as np
import pandas as pd
import datetime

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load Data and Preprocessing

# %%
train_df = pd.read_csv ('./datasets/train.csv')
train_df.head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId  socialEngagementType     visitId  \
# 0  1131660440785968503_1472830385  Not Socially Engaged  1472830385
# 1   377306020877927890_1472880147  Not Socially Engaged  1472880147
# 2  3895546263509774583_1472865386  Not Socially Engaged  1472865386
# 3  4763447161404445595_1472881213  Not Socially Engaged  1472881213
# 4    27294437909732085_1472822600  Not Socially Engaged  1472822600
#
#    visitNumber  visitStartTime device.browser  device.browserSize  \
# 0            1      1472830385         Chrome                 NaN
# 1            1      1472880147        Firefox                 NaN
# 2            1      1472865386         Chrome                 NaN
# 3            1      1472881213     UC Browser                 NaN
# 4            2      1472822600         Chrome                 NaN
#
#            ...           trafficSource.adwordsClickInfo.isVideoAd  \
# 0          ...                                                NaN
# 1          ...                                                NaN
# 2          ...                                                NaN
# 3          ...                                                NaN
# 4          ...                                                NaN
#
#   trafficSource.adwordsClickInfo.page  trafficSource.adwordsClickInfo.slot  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#    trafficSource.campaign  trafficSource.campaignCode  \
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN
#
#    trafficSource.isTrueDirect  trafficSource.keyword  trafficSource.medium  \
# 0                         NaN                    NaN               organic
# 1                         NaN                    NaN               organic
# 2                         NaN                    NaN               organic
# 3                         NaN        google + online               organic
# 4                        True                    NaN               organic
#
#    trafficSource.referralPath  trafficSource.source
# 0                         NaN                google
# 1                         NaN                google
# 2                         NaN                google
# 3                         NaN                google
# 4                         NaN                google
#
# [5 rows x 55 columns]

# %%
test_df = pd.read_csv('./datasets/test.csv')
test_df.head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20171016  6167871330617112363
# 1  Organic Search  20171016  0643697640977915618
# 2  Organic Search  20171016  6059383810968229466
# 3  Organic Search  20171016  2376720078563423631
# 4  Organic Search  20171016  2314544520795440038
#
#                         sessionId  socialEngagementType     visitId  \
# 0  6167871330617112363_1508151024  Not Socially Engaged  1508151024
# 1  0643697640977915618_1508175522  Not Socially Engaged  1508175522
# 2  6059383810968229466_1508143220  Not Socially Engaged  1508143220
# 3  2376720078563423631_1508193530  Not Socially Engaged  1508193530
# 4  2314544520795440038_1508217442  Not Socially Engaged  1508217442
#
#    visitNumber  visitStartTime device.browser  device.browserSize  \
# 0            2      1508151024         Chrome                 NaN
# 1            1      1508175522         Chrome                 NaN
# 2            1      1508143220         Chrome                 NaN
# 3            1      1508193530         Safari                 NaN
# 4            1      1508217442         Safari                 NaN
#
#            ...           trafficSource.adwordsClickInfo.gclId  \
# 0          ...                                            NaN
# 1          ...                                            NaN
# 2          ...                                            NaN
# 3          ...                                            NaN
# 4          ...                                            NaN
#
#   trafficSource.adwordsClickInfo.isVideoAd  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    trafficSource.adwordsClickInfo.page  trafficSource.adwordsClickInfo.slot  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3                                  NaN                                  NaN
# 4                                  NaN                                  NaN
#
#    trafficSource.campaign  trafficSource.isTrueDirect  trafficSource.keyword  \
# 0                     NaN                        True                    NaN
# 1                     NaN                         NaN                    NaN
# 2                     NaN                         NaN                    NaN
# 3                     NaN                         NaN                    NaN
# 4                     NaN                         NaN                    NaN
#
#    trafficSource.medium  trafficSource.referralPath  trafficSource.source
# 0               organic                         NaN                google
# 1               organic                         NaN                google
# 2               organic                         NaN                google
# 3               organic                         NaN                google
# 4               organic                         NaN                google
#
# [5 rows x 53 columns]

# %%
dif_col = [col for col in train_df.columns if col not in test_df.columns]
print('There are {} columns in train data and not in test data : \n{}'.format(len(dif_col),dif_col))
# Out:
# There are 2 columns in train data and not in test data :
# ['totals.transactionRevenue', 'trafficSource.campaignCode']

# %%
cols_to_drop = [col for col in train_df.columns if train_df[col].nunique(dropna = False) == 1]
print('{} columns containing no information or only 1 data,will be dropped for further analysis, including: \n{}'.format(len(cols_to_drop), cols_to_drop))
# Out:
# 19 columns containing no information or only 1 data,will be dropped for further analysis, including:
# ['socialEngagementType', 'device.browserSize', 'device.browserVersion', 'device.flashVersion', 'device.language', 'device.mobileDeviceBranding', 'device.mobileDeviceInfo', 'device.mobileDeviceMarketingName', 'device.mobileDeviceModel', 'device.mobileInputSelector', 'device.operatingSystemVersion', 'device.screenColors', 'device.screenResolution', 'geoNetwork.cityId', 'geoNetwork.latitude', 'geoNetwork.longitude', 'geoNetwork.networkLocation', 'totals.visits', 'trafficSource.adwordsClickInfo.criteriaParameters']

# %%
# drop the empty columns and the one column that's not included in test data

train_df.drop(cols_to_drop + ['trafficSource.campaignCode'], axis=1, inplace=True)
test_df.drop(cols_to_drop, axis=1, inplace=True)
train_df.head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId     visitId  visitNumber  visitStartTime  \
# 0  1131660440785968503_1472830385  1472830385            1      1472830385
# 1   377306020877927890_1472880147  1472880147            1      1472880147
# 2  3895546263509774583_1472865386  1472865386            1      1472865386
# 3  4763447161404445595_1472881213  1472881213            1      1472881213
# 4    27294437909732085_1472822600  1472822600            2      1472822600
#
#   device.browser device.deviceCategory  device.isMobile          ...           \
# 0         Chrome               desktop            False          ...
# 1        Firefox               desktop            False          ...
# 2         Chrome               desktop            False          ...
# 3     UC Browser               desktop            False          ...
# 4         Chrome                mobile             True          ...
#
#   trafficSource.adwordsClickInfo.gclId  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   trafficSource.adwordsClickInfo.isVideoAd  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#   trafficSource.campaign trafficSource.isTrueDirect trafficSource.keyword  \
# 0                    NaN                        NaN                   NaN
# 1                    NaN                        NaN                   NaN
# 2                    NaN                        NaN                   NaN
# 3                    NaN                        NaN       google + online
# 4                    NaN                       True                   NaN
#
#   trafficSource.medium  trafficSource.referralPath  trafficSource.source
# 0              organic                         NaN                google
# 1              organic                         NaN                google
# 2              organic                         NaN                google
# 3              organic                         NaN                google
# 4              organic                         NaN                google
#
# [5 rows x 35 columns]

# %%
gc.collect()

def NaN_stat(df):
    missing_vl = pd.DataFrame(df.isnull().sum(), columns = ['Count'])
    missing_vl['Percent(%)'] = round(missing_vl['Count']/len(df) * 100, 2)
    missing_vl = missing_vl.sort_values('Count')
    return missing_vl
train_missing = NaN_stat(train_df)
train_missing
# Out:
#                                                Count  Percent(%)
# channelGrouping                                    0        0.00
# date                                               0        0.00
# fullVisitorId                                      0        0.00
# sessionId                                          0        0.00
# visitId                                            0        0.00
# visitNumber                                        0        0.00
# visitStartTime                                     0        0.00
# device.deviceCategory                              0        0.00
# device.isMobile                                    0        0.00
# totals.hits                                        0        0.00
# device.browser                                     8        0.00
# trafficSource.source                              69        0.01
# totals.pageviews                                 100        0.01
# trafficSource.medium                             120        0.01
# geoNetwork.continent                            1468        0.16
# geoNetwork.subContinent                         1468        0.16
# geoNetwork.country                              1468        0.16
# device.operatingSystem                          4695        0.52
# totals.newVisits                              200593       22.20
# geoNetwork.networkDomain                      244881       27.10
# totals.bounces                                453023       50.13
# geoNetwork.region                             536056       59.32
# geoNetwork.city                               542491       60.03
# trafficSource.referralPath                    572712       63.38
# trafficSource.isTrueDirect                    629648       69.68
# geoNetwork.metro                              709995       78.57
# trafficSource.campaign                        865347       95.76
# trafficSource.keyword                         869292       96.20
# trafficSource.adwordsClickInfo.gclId          882092       97.61
# trafficSource.adwordsClickInfo.page           882193       97.63
# trafficSource.adwordsClickInfo.isVideoAd      882193       97.63
# trafficSource.adwordsClickInfo.adNetworkType  882193       97.63
# trafficSource.adwordsClickInfo.slot           882193       97.63
# totals.transactionRevenue                     892138       98.73
# trafficSource.adContent                       892707       98.79

# %%
test_missing = NaN_stat(test_df)
missingdata_df = train_missing.merge(test_missing, left_index = True, right_index = True)
missingdata_df
# Out:
#                                               Count_x  Percent(%)_x  Count_y  \
# channelGrouping                                     0          0.00        0
# date                                                0          0.00        0
# fullVisitorId                                       0          0.00        0
# sessionId                                           0          0.00        0
# visitId                                             0          0.00        0
# visitNumber                                         0          0.00        0
# visitStartTime                                      0          0.00        0
# device.deviceCategory                               0          0.00        0
# device.isMobile                                     0          0.00        0
# totals.hits                                         0          0.00        0
# device.browser                                      8          0.00        4
# trafficSource.source                               69          0.01        1
# totals.pageviews                                  100          0.01      139
# trafficSource.medium                              120          0.01       17
# geoNetwork.continent                             1468          0.16     1049
# geoNetwork.subContinent                          1468          0.16     1049
# geoNetwork.country                               1468          0.16     1049
# device.operatingSystem                           4695          0.52     7120
# totals.newVisits                               200593         22.20   200314
# geoNetwork.networkDomain                       244881         27.10   254168
# totals.bounces                                 453023         50.13   383736
# geoNetwork.region                              536056         59.32   446677
# geoNetwork.city                                542491         60.03   456335
# trafficSource.referralPath                     572712         63.38   569361
# trafficSource.isTrueDirect                     629648         69.68   544171
# geoNetwork.metro                               709995         78.57   609860
# trafficSource.campaign                         865347         95.76   728927
# trafficSource.keyword                          869292         96.20   737423
# trafficSource.adwordsClickInfo.gclId           882092         97.61   750822
# trafficSource.adwordsClickInfo.page            882193         97.63   750870
# trafficSource.adwordsClickInfo.isVideoAd       882193         97.63   750870
# trafficSource.adwordsClickInfo.adNetworkType   882193         97.63   750870
# trafficSource.adwordsClickInfo.slot            882193         97.63   750870
# trafficSource.adContent                        892707         98.79   750893
#
#                                               Percent(%)_y
# channelGrouping                                       0.00
# date                                                  0.00
# fullVisitorId                                         0.00
# sessionId                                             0.00
# visitId                                               0.00
# visitNumber                                           0.00
# visitStartTime                                        0.00
# device.deviceCategory                                 0.00
# device.isMobile                                       0.00
# totals.hits                                           0.00
# device.browser                                        0.00
# trafficSource.source                                  0.00
# totals.pageviews                                      0.02
# trafficSource.medium                                  0.00
# geoNetwork.continent                                  0.13
# geoNetwork.subContinent                               0.13
# geoNetwork.country                                    0.13
# device.operatingSystem                                0.88
# totals.newVisits                                     24.89
# geoNetwork.networkDomain                             31.59
# totals.bounces                                       47.69
# geoNetwork.region                                    55.51
# geoNetwork.city                                      56.71
# trafficSource.referralPath                           70.76
# trafficSource.isTrueDirect                           67.63
# geoNetwork.metro                                     75.79
# trafficSource.campaign                               90.59
# trafficSource.keyword                                91.64
# trafficSource.adwordsClickInfo.gclId                 93.31
# trafficSource.adwordsClickInfo.page                  93.31
# trafficSource.adwordsClickInfo.isVideoAd             93.31
# trafficSource.adwordsClickInfo.adNetworkType         93.31
# trafficSource.adwordsClickInfo.slot                  93.31
# trafficSource.adContent                              93.32

# %%
feature_drop = [i for i in missingdata_df.index if missingdata_df.loc[i,'Percent(%)_x']> 40 and missingdata_df.loc[i,'Percent(%)_y']> 40]
print('{} columns containing ~ 50% missing values in both train and test data, will be dropped for further analysis, including: \n{}'.format(len(feature_drop), feature_drop))
# Out:
# 14 columns containing ~ 50% missing values in both train and test data, will be dropped for further analysis, including:
# ['totals.bounces', 'geoNetwork.region', 'geoNetwork.city', 'trafficSource.referralPath', 'trafficSource.isTrueDirect', 'geoNetwork.metro', 'trafficSource.campaign', 'trafficSource.keyword', 'trafficSource.adwordsClickInfo.gclId', 'trafficSource.adwordsClickInfo.page', 'trafficSource.adwordsClickInfo.isVideoAd', 'trafficSource.adwordsClickInfo.adNetworkType', 'trafficSource.adwordsClickInfo.slot', 'trafficSource.adContent']

# %%
train_df.drop(columns = feature_drop, inplace=True)
test_df.drop(columns = feature_drop, inplace=True)
train_df.head()
# Out:
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId     visitId  visitNumber  visitStartTime  \
# 0  1131660440785968503_1472830385  1472830385            1      1472830385
# 1   377306020877927890_1472880147  1472880147            1      1472880147
# 2  3895546263509774583_1472865386  1472865386            1      1472865386
# 3  4763447161404445595_1472881213  1472881213            1      1472881213
# 4    27294437909732085_1472822600  1472822600            2      1472822600
#
#   device.browser device.deviceCategory  device.isMobile         ...           \
# 0         Chrome               desktop            False         ...
# 1        Firefox               desktop            False         ...
# 2         Chrome               desktop            False         ...
# 3     UC Browser               desktop            False         ...
# 4         Chrome                mobile             True         ...
#
#   geoNetwork.continent geoNetwork.country geoNetwork.networkDomain  \
# 0                 Asia             Turkey             ttnet.com.tr
# 1              Oceania          Australia              dodo.net.au
# 2               Europe              Spain          unknown.unknown
# 3                 Asia          Indonesia          unknown.unknown
# 4               Europe     United Kingdom          unknown.unknown
#
#   geoNetwork.subContinent totals.hits  totals.newVisits  totals.pageviews  \
# 0            Western Asia           1               1.0               1.0
# 1             Australasia           1               1.0               1.0
# 2         Southern Europe           1               1.0               1.0
# 3          Southeast Asia           1               1.0               1.0
# 4         Northern Europe           1               NaN               1.0
#
#    totals.transactionRevenue  trafficSource.medium trafficSource.source
# 0                        NaN               organic               google
# 1                        NaN               organic               google
# 2                        NaN               organic               google
# 3                        NaN               organic               google
# 4                        NaN               organic               google
#
# [5 rows x 21 columns]

# %%
print(train_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903653 entries, 0 to 903652
# Data columns (total 21 columns):
# channelGrouping              903653 non-null object
# date                         903653 non-null int64
# fullVisitorId                903653 non-null object
# sessionId                    903653 non-null object
# visitId                      903653 non-null int64
# visitNumber                  903653 non-null int64
# visitStartTime               903653 non-null int64
# device.browser               903645 non-null object
# device.deviceCategory        903653 non-null object
# device.isMobile              903653 non-null bool
# device.operatingSystem       898958 non-null object
# geoNetwork.continent         902185 non-null object
# geoNetwork.country           902185 non-null object
# geoNetwork.networkDomain     658772 non-null object
# geoNetwork.subContinent      902185 non-null object
# totals.hits                  903653 non-null int64
# totals.newVisits             703060 non-null float64
# totals.pageviews             903553 non-null float64
# totals.transactionRevenue    11515 non-null float64
# trafficSource.medium         903533 non-null object
# trafficSource.source         903584 non-null object
# dtypes: bool(1), float64(3), int64(5), object(12)
# memory usage: 138.7+ MB
# None

# %%
# process date into datetime format
train_df['date'] = train_df['date'].apply(lambda x: datetime.date(int(str(x)[:4]), int(str(x)[4:6]), int(str(x)[6:])))
test_df['date'] = test_df['date'].apply(lambda x: datetime.date(int(str(x)[:4]), int(str(x)[4:6]), int(str(x)[6:])))

# %%
# fill empty revenue cell with 0
train_df['totals.transactionRevenue'] = train_df['totals.transactionRevenue'].fillna(value=0)

# %%
print('Train data sample size : {} \nTest data sample size : {} \nNumber of features to further explore: {} '
      .format(len(train_df), len(test_df), len(test_df.columns)))

print('Within these features: \n   visitId has the same value as visitStartTime \n   sessionId has the combined information of fullVisitorId and visitId')
# Out:
# Train data sample size : 903653
# Test data sample size : 804684
# Number of features to further explore: 20
# Within these features:
#    visitId has the same value as visitStartTime
#    sessionId has the combined information of fullVisitorId and visitId

# %%
# save processed train and test data for further analysis
output_dir = os.path.join('./', 'Output')
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
train_df.to_csv(os.path.join(output_dir, 'train_p.csv'))
test_df.to_csv(os.path.join(output_dir, 'test_p.csv'))
